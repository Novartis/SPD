# %% [markdown]
# # Notebook #5

# %% [markdown]
# Jeffrey Sutherland
# 8/31/2021

# %%
import pandas as pd
import numpy as np
import pickle
import numpy
import os
from collections import defaultdict
from sklearn.metrics import roc_auc_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import l1_min_c
from sklearn.model_selection import train_test_split

# %%
PATH_DATA_INPUT = "../data/input/"
PATH_DATA_INTERMEDIATE = "../data/intermediate/"
PATH_DATA_OUTPUT = "../data/output/"
PATH_MODELS = '../data/models/'

# %% [markdown]
# Set the number of trials (folds) of leave 20% out cross validation
# testmode = True causes data frames to be written out

# %%
numtrials = 50
testmode = False

# %% [markdown]
# read the adverse event (FAERS, SIDER) positive and negatives from the pickled output of make_AE_training_sets.ipynb

# %%
with open(PATH_DATA_INTERMEDIATE + 'AE_training_sets.pkl', 'rb') as inf:
    AE_data = pickle.load(inf)

print('Read in AE pickle; top level keys are {}'.format(AE_data.keys()))
# Out:
# Read in AE pickle; top level keys are dict_keys(['SIDER:PT', 'SIDER:HT', 'SIDER:HG', 'FAERS:PT', 'FAERS:HT', 'FAERS:HG', 'SIDER_DRUGS', 'FAERS_DRUGS'])

# %% [markdown]
# read the picked activity dataset from make_AE_vs_activity_dataset.ipynb

# %%
with open(PATH_DATA_INTERMEDIATE + 'activity_training_sets_pub.pkl', 'rb') as inf:
    assay_data = pickle.load(inf)

print('Read in assay pickle; number of assay groups at top level: {}'.format(len(assay_data)))
# Out:
# Read in assay pickle; number of assay groups at top level: 168

# %% [markdown]
# read the thresholds to apply to IC50 and margins - established by analyzing data from the calc_AE_vs_assay_score.ipynb
# notebook

# %%
# input from the univartiate analysis done in spotfire
thresholds = pd.read_csv(PATH_DATA_INPUT + 'assay_vs_param_thresholds_update.txt', sep='\t')
thresholds.head(5)
# Out:
#   assay_group             param  threshold
# 0       10942       cmax_margin         10
# 1       10942              ic50         30
# 2       10943              ic50         30
# 3       13013       cmax_margin         10
# 4       13013  free_cmax_margin        100

# %% [markdown]
# read the dataset of AE MedDRA codes vs. assay groups to use in the model building process

# %%
ae_assay_pairs = pd.read_csv(PATH_DATA_INPUT + 'AE_vs_assay_pairs_logistic_modelling_update.txt', sep='\t')
ae_assay_pairs.head(5)
# Out:
#        code type               assay source  \
# 0  10000125   PT                3124  SIDER
# 1  10000125   PT  3197, 41523, 42786  SIDER
# 2  10000125   PT                5426  SIDER
# 3  10000389   PT                3124  SIDER
# 4  10000389   PT                3126  SIDER
#
#                      significant types
# 0                                 ic50
# 1  cmax_margin, free_cmax_margin, ic50
# 2                                 ic50
# 3                                 ic50
# 4                     free_cmax_margin

# %% [markdown]
# Function to prepare a dataframe with AE coded as True/False and columns for the selected parameters and assay combinations
#
# When performing statistical associations between AEs and activity results, results with IC50 qualifier (and hence
# Cmax and free Cmax margin) are censored according to the tresholds read in from prior computation
#
# Only assay + activity result types having 70% or more of the maximum assay result count (for margin-type results) is
# retained
#
# Returns a dataframe

# %%
def make_model_df(code, tp, source, assay_vs_type):

    pair = source + ':' + tp
    if AE_data.get(pair, None) is None:
        print('Failed to find AE info for pair {}; skipping'.format(pair))
        return None

    pos = list(AE_data[pair][code]['pos'])
    neg = list(AE_data[pair][code]['neg'])
    both = pos + neg
    outcomes = [1 for x in pos] + [0 for y in neg]
    df = pd.DataFrame(zip(both, outcomes), columns = ['struct_id', 'outcomes'])
    # track compounds that have at least one margin value; don't want a dataframe with NaNs for all drugs where
    # cmax, PPB was not available (i.e. we require at least one margin - free or total - to be significant in this analysis)
    have_margin = set()

    # track number of margin values by assay, to remove assays with too many missing values
    assay_count = dict()

    for assay in assay_vs_type['assay'].unique():

        # trying to use all 3 result types regardless of whether they were individually significant at our univariate cutoff
        # because the tresholds data frame excludes any assay - parameter type without any significant associations
        # at p-kw <= 1E-03, there will be logging below indicating skipped pairs
        sig_types = ['ic50', 'cmax_margin', 'free_cmax_margin']

        for param in sig_types:
            # get the pre-selected cutoff for this assay and result type (ic50, cmax_margin, free_cmax_margin) pair
            try:
                cutoff = thresholds[ (thresholds['assay_group'] == assay) & (thresholds['param'] == param) ]['threshold'].iloc[0]
            except:
                print('Failed to get cutoff for assay {} vs. param type {}; skipping'.format(assay, param))
                continue

            label = assay + '|' + param
            simplified = dict()
            numvals = 0
            for c in both:
                if assay_data[assay].get(c, None) is None:
                    # no data
                    continue
                elif assay_data[assay][c][param] is None or numpy.isnan(assay_data[assay][c][param]):
                    # happens for Cmax or free Cmax where IC50 was avail but not the exposure, hence these are NaN
                    continue
                elif assay_data[assay][c]['prefix'] == '>' and assay_data[assay][c][param] < cutoff:
                    continue
                elif assay_data[assay][c][param] > cutoff:
                    simplified[c] = np.log10(cutoff)
                    numvals += 1
                    if param in ['free_cmax_margin', 'cmax_margin']:
                        have_margin.add(c)
                else:
                    simplified[c] = np.log10(assay_data[assay][c][param])
                    numvals += 1
                    if param in ['free_cmax_margin', 'cmax_margin']:
                        have_margin.add(c)

            assay_count[label] = numvals
            df[label] = df['struct_id'].map(simplified)

    # because all 3 activity measures are used for each assay, this is an OK way to find the subset
    # of compounds that have margins.  With the original as intended approach (i.e. receiving the
    # measure as a parameter), a single margin-based measure could be too contraining and result in the
    # eliminatinion of many drugs - i.e. an assay with little data for which compounds with assay data
    # and human Cmax << compounds with human Cmax
    df = df[ df['struct_id'].isin(have_margin) ]

    if testmode:
        filename = PATH_MODELS + 'model_matrix_preimpute_code_{}_source_{}.csv'.format(code, source)
        df.to_csv(filename, index=False)

    # determine which assay (for margin-type results) has the max result count
    maxmargin = next(filter(lambda x: 'margin' in x, sorted(assay_count.keys(), key=lambda x: assay_count[x], reverse=True)))
    maxcount = assay_count[maxmargin]

    dropcols = list()
    for assay in assay_count:
        if assay_count[assay]/maxcount < 0.7:
            dropcols.append(assay)
        # use median assay value where missing
        else:
            df[assay]=df[assay].fillna(df[assay].median())

    print('Removing columns with more than 30% missing values: {}'.format(dropcols))
    df.drop(columns=dropcols, inplace=True)

    return df

# %% [markdown]
# Function to build lasso (l1)-penalized logistic regression models from data frame using dataframe with struct_id
# on column 1, AE category on column 2 and assays on 3+
#
# Returns a dictionary with various results.  See paper methods
#
# adapted from https://chrisalbon.com/code/machine_learning/logistic_regression/logistic_regression_with_l1_regularization/
# and https://scikit-learn.org/stable/auto_examples/linear_model/plot_logistic_path.html

# %%
def build_model_from_df(model_df):

    y = model_df.iloc[:,1]
    X = model_df.iloc[:,2:]

    # sequence of penalization parameters 'c' for l1 penalized logistic regression
    c_seq = l1_min_c(X, y, loss='log')*np.logspace(0, 5, 20)
    clf = LogisticRegression(penalty='l1', solver='saga', max_iter=10000, warm_start=True)

    test_accuracy = defaultdict(list)
    nonzero_coefs = defaultdict(dict)
    nonzero_coef_count = defaultdict(list)
    features = list(X.columns)

    trial = 0

    while trial < numtrials:

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

        # skip any splits without both classes in train and test - ROC AUC calc fails
        if len(np.unique(y_test)) < 2 or len(np.unique(y_train)) < 2:
            continue

        for c in c_seq:
            clf.set_params(C=c)
            clf.fit(X_train, y_train)
            these_coefs = clf.coef_.ravel().copy()
            nonzero_coef_count[c].append(np.count_nonzero(these_coefs))
            roc_auc = roc_auc_score(y_test, clf.predict_proba(X_test)[:, 1])
            test_accuracy[c].append(roc_auc)

            # track which assays have non-zero coefs at each iteration
            for i in range(len(these_coefs)):
                if these_coefs[i] != 0:
                    feature = features[i]
                    nonzero_coefs[c][feature] = nonzero_coefs[c].get(feature, 0) + 1
        trial += 1

    summary_stats = list()
    max_error_adjuted_accuracy = 0
    max_accuracy_c = None
    sparse_accuracy_c = None

    # summarize results at each L1 penalty
    for c in c_seq:
        # get average and stderr accuracy
        avg_accuracy = np.mean(test_accuracy[c])
        sem_accuracy = np.std(test_accuracy[c], ddof=1)/np.sqrt(numtrials)
        avg_feature_count = np.mean(nonzero_coef_count[c])
        error_adjusted_accuracy =  avg_accuracy - sem_accuracy

        if error_adjusted_accuracy > max_error_adjuted_accuracy:
            max_error_adjuted_accuracy = error_adjusted_accuracy
            max_accuracy_c = c

        summary_stats.append({'c': c, 'is_max_AUC': False, 'is_1se_AUC': False, 'avg_AUC': avg_accuracy,
                              'sem_AUC': sem_accuracy, 'avg_feature_count': avg_feature_count, 'n': numtrials})

    # loop back through c values and annotate them as the best one or the one within 1se of best
    for r in summary_stats:
        if sparse_accuracy_c is None and r['avg_AUC'] >= max_error_adjuted_accuracy:
            r['is_1se_AUC'] = True
            sparse_accuracy_c = r['c']
        if r['c'] == max_accuracy_c:
            r['is_max_AUC'] = True

    if sparse_accuracy_c is None:
        print('Failed to find c giving model within 1SE of best model; error')
        return None

    # build final models on complete set to determine order of variable (feature) appearance into model
    variable_order = dict()
    variable_count = 0
    sparse_coefs = dict()
    max_coefs = dict()

    for c in c_seq:
        clf.set_params(C=c)
        clf.fit(X, y)
        these_coefs = clf.coef_.ravel()

        # track which assays have non-zero coefs at each iteration; multiple can appear on same iteration
        new_variables = list()
        for i in range(len(these_coefs)):

            feature = features[i]
            if c == sparse_accuracy_c:
                sparse_coefs[feature] = these_coefs[i]

            if c == max_accuracy_c:
                max_coefs[feature] = these_coefs[i]

            if these_coefs[i] != 0 and variable_order.get(feature, None) is None:
                new_variables.append(feature)

        if not new_variables:
            continue

        # if variables are tied by order of appearance (come in at same penalty c value), use avg rank
        avg_rank = np.mean(range(variable_count+1, len(new_variables)+variable_count+1))
        variable_count += len(new_variables)
        for v in new_variables:
            variable_order[v] = avg_rank

    results = {'CV_stats': summary_stats, 'CV_variable_use': nonzero_coefs, 'max_AUC_c': max_accuracy_c,
               '1se_AUC_c': sparse_accuracy_c, 'variables':[]}
    for v in features:
        # it's possible to have some dataset variables that fail to be used at any shrinkage param - use defaults below
        results['variables'].append({'variable': v, 'variable_order': variable_order.get(v, 999),
                                     '1se_AUC_coef': sparse_coefs.get(v, 0), 'max_AUC_coef': max_coefs.get(v, 0)})
    return results

# %%
combined_cv_stats = list()
combined_variables = list()
combined_cv_variables = list()

for code in ae_assay_pairs['code'].unique():

    # code type is 1:1 with code; just take first one
    tp = ae_assay_pairs[ (ae_assay_pairs['code'] == code) ]['type'].iloc[0]
    for source in ae_assay_pairs[ (ae_assay_pairs['code'] == code)]['source'].unique():

        assay_vs_type = ae_assay_pairs[ (ae_assay_pairs['code'] == code) & (ae_assay_pairs['source'] == source) ][['assay', 'significant types']]
        model_df = make_model_df(code, tp, source, assay_vs_type)

        if testmode:
            filename = PATH_MODELS + 'model_matrix_code_{}_source_{}.csv'.format(code, source)
            model_df.to_csv(filename, index=False)

        model_results = build_model_from_df(model_df)

        if model_results is None:
            print('Error in building models for code {} vs. source {} pair; skipping'.format(code, source))
            continue

        for r in model_results['CV_stats']:
            r['code'] = code
            r['source'] = source
            combined_cv_stats.append(r)

        for r in model_results['variables']:
            r['code'] = code
            r['source'] = source
            combined_variables.append(r)

        c_count = 0
        for c in model_results['CV_variable_use']:
            c_count += 1
            for v in model_results['CV_variable_use'][c]:
                combined_cv_variables.append({'c': c, 'c_seq': c_count, 'variable': v, 'count': model_results['CV_variable_use'][c][v], 'code': code, 'source': source})

        print('Done code {} vs. source {}'.format(code, source))
# Out:
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: []
# Done code 10000125 vs. source SIDER
# Failed to get cutoff for assay 3132 vs. param type cmax_margin; skipping
# Failed to get cutoff for assay 3132 vs. param type free_cmax_margin; skipping
# Failed to get cutoff for assay 3160 vs. param type cmax_margin; skipping
# Failed to get cutoff for assay 3160 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3124|cmax_margin', '3124|free_cmax_margin', '3130|free_cmax_margin', '3131|free_cmax_margin', '3132|ic50', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3160|ic50', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin', '5363|ic50', '5363|cmax_margin', '5363|free_cmax_margin']
# Done code 10000389 vs. source SIDER
# Removing columns with more than 30% missing values: ['3130|free_cmax_margin', '3157|free_cmax_margin']
# Done code 10001275 vs. source SIDER
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10001341 vs. source FAERS
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10001341 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10001343 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10001353 vs. source FAERS
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10001353 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin']
# Done code 10001382 vs. source SIDER
# Removing columns with more than 30% missing values: ['3162|cmax_margin', '3162|free_cmax_margin']
# Done code 10001488 vs. source FAERS
# Removing columns with more than 30% missing values: ['3124|free_cmax_margin']
# Done code 10001488 vs. source SIDER
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3126|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '32309|ic50', '32309|cmax_margin', '49102|free_cmax_margin', '5426|cmax_margin']
# Done code 10001497 vs. source FAERS
# Removing columns with more than 30% missing values: []
# Done code 10001497 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3088, 41625|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3130|cmax_margin', '3130|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3175|cmax_margin', '3175|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3235|cmax_margin', '3235|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5426|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10001540 vs. source FAERS
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3126|free_cmax_margin', '3130|cmax_margin', '3130|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '41704, 42863|ic50', '41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin', '49102|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5434|ic50', '5434|cmax_margin', '5434|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10001540 vs. source SIDER
# Failed to get cutoff for assay 37928, 41747 vs. param type free_cmax_margin; skipping
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3083|ic50', '3083|cmax_margin', '3083|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3196, 42784|ic50', '3196, 42784|cmax_margin', '3196, 42784|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '37928, 41747|cmax_margin', '41704, 42863|ic50', '41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin', '49102|free_cmax_margin', '5426|ic50', '5426|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10001541 vs. source SIDER
# Removing columns with more than 30% missing values: ['3157|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin']
# Done code 10001854 vs. source FAERS
# Removing columns with more than 30% missing values: []
# Done code 10001854 vs. source SIDER
# Removing columns with more than 30% missing values: ['3235|cmax_margin', '3235|free_cmax_margin']
# Done code 10001949 vs. source FAERS
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3130|ic50', '3130|cmax_margin', '3130|free_cmax_margin', '3131|cmax_margin', '3131|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '41704, 42863|ic50', '41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin', '49102|free_cmax_margin', '5363|ic50', '5363|cmax_margin', '5363|free_cmax_margin', '5449|free_cmax_margin']
# Done code 10002500 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10002652 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3196, 42784|ic50', '3196, 42784|cmax_margin', '3196, 42784|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5426|ic50', '5426|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10002700 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10002701 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3126|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '5426|cmax_margin']
# Done code 10002855 vs. source FAERS
# Removing columns with more than 30% missing values: ['3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin']
# Done code 10002855 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10002967 vs. source SIDER
# Removing columns with more than 30% missing values: ['3131|cmax_margin', '3131|free_cmax_margin']
# Done code 10003068 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10003119 vs. source FAERS
# Failed to get cutoff for assay 3187 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3134, 18942|free_cmax_margin', '3187|ic50', '3187|cmax_margin']
# Done code 10003119 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10003486 vs. source FAERS
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3159|cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3175|cmax_margin', '3175|free_cmax_margin', '3295, 41519|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin']
# Done code 10003497 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin']
# Done code 10003591 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10003671 vs. source SIDER
# Removing columns with more than 30% missing values: ['41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10003694 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3295, 41519|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin']
# Done code 10003840 vs. source SIDER
# Removing columns with more than 30% missing values: ['3162|cmax_margin', '3162|free_cmax_margin']
# Done code 10004209 vs. source FAERS
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10004994 vs. source FAERS
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10005049 vs. source FAERS
# Removing columns with more than 30% missing values: ['41633|cmax_margin', '41633|free_cmax_margin']
# Done code 10005140 vs. source SIDER
# Removing columns with more than 30% missing values: ['41699|cmax_margin']
# Done code 10005734 vs. source FAERS
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin']
# Done code 10005734 vs. source SIDER
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin', '3159|free_cmax_margin', '41699|cmax_margin', '41699|free_cmax_margin']
# Done code 10005750 vs. source FAERS
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '5426|ic50', '5426|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|free_cmax_margin']
# Done code 10005780 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3162|cmax_margin', '3162|free_cmax_margin']
# Done code 10005907 vs. source FAERS
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3157|free_cmax_margin']
# Done code 10005910 vs. source SIDER
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3088, 41625|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10006100 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10006187 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['31453|cmax_margin', '41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin']
# Done code 10006223 vs. source SIDER
# Failed to get cutoff for assay 3259, 16800, 18311 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3159|free_cmax_margin', '3259, 16800, 18311|cmax_margin', '3295, 41519|free_cmax_margin']
# Done code 10006240 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3124|free_cmax_margin', '3157|free_cmax_margin', '5363|cmax_margin', '5363|free_cmax_margin']
# Done code 10006242 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10006287 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10006288 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10006290 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10006313 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10006473 vs. source FAERS
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin']
# Done code 10006482 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10007134 vs. source FAERS
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin']
# Done code 10007554 vs. source FAERS
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin']
# Done code 10007554 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10007764 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10007776 vs. source FAERS
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3087|cmax_margin', '3087|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10007776 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10008183 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10008352 vs. source SIDER
# Removing columns with more than 30% missing values: ['3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin']
# Done code 10008401 vs. source FAERS
# Removing columns with more than 30% missing values: ['3184, 14955, 15257, 41517, 42788|free_cmax_margin', '5425|free_cmax_margin']
# Done code 10008401 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['31453|cmax_margin', '41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin']
# Done code 10008570 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3295, 41519|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '49102|free_cmax_margin', '5426|ic50', '5426|cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10008752 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '5426|ic50', '5426|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|free_cmax_margin']
# Done code 10008754 vs. source SIDER
# Removing columns with more than 30% missing values: ['3264|cmax_margin', '3264|free_cmax_margin']
# Done code 10009653 vs. source SIDER
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3081|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3175|cmax_margin', '3175|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3196, 42784|ic50', '3196, 42784|cmax_margin', '3196, 42784|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10009848 vs. source SIDER
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin']
# Done code 10009895 vs. source SIDER
# Failed to get cutoff for assay 3259, 16800, 18311 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3131|cmax_margin', '3131|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3259, 16800, 18311|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin']
# Done code 10010276 vs. source SIDER
# Removing columns with more than 30% missing values: ['3124|free_cmax_margin', '3157|free_cmax_margin', '3162|cmax_margin', '3162|free_cmax_margin']
# Done code 10010774 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10010893 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10010947 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10011570 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10011652 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10011655 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10011827 vs. source FAERS
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3124|cmax_margin', '3124|free_cmax_margin', '3130|free_cmax_margin', '3157|free_cmax_margin', '3197, 41523, 42786|free_cmax_margin', '41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5426|cmax_margin', '5434|cmax_margin', '5434|free_cmax_margin']
# Done code 10011953 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10011975 vs. source FAERS
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3157|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '5425|free_cmax_margin']
# Done code 10011975 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10012239 vs. source FAERS
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3124|free_cmax_margin', '3130|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '5363|free_cmax_margin']
# Done code 10012239 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10012259 vs. source FAERS
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3124|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '5363|free_cmax_margin']
# Done code 10012259 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3124|cmax_margin', '3124|free_cmax_margin', '3125|ic50', '3235|cmax_margin', '3235|free_cmax_margin']
# Done code 10012335 vs. source SIDER
# Removing columns with more than 30% missing values: ['3124|free_cmax_margin', '3159|free_cmax_margin', '3162|cmax_margin', '3162|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin']
# Done code 10012373 vs. source FAERS
# Removing columns with more than 30% missing values: ['3124|free_cmax_margin', '3159|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin']
# Done code 10012373 vs. source SIDER
# Failed to get cutoff for assay 41675 vs. param type cmax_margin; skipping
# Failed to get cutoff for assay 41675 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['41675|ic50']
# Done code 10012378 vs. source FAERS
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10012432 vs. source SIDER
# Removing columns with more than 30% missing values: ['3163, 16324, 17275|free_cmax_margin']
# Done code 10012656 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10013305 vs. source FAERS
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3081|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3126|free_cmax_margin', '3130|ic50', '3130|cmax_margin', '3130|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '49102|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5434|ic50', '5434|cmax_margin', '5434|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013316 vs. source SIDER
# Removing columns with more than 30% missing values: ['3124|free_cmax_margin']
# Done code 10013322 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3126|free_cmax_margin', '3295, 41519|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin']
# Done code 10013356 vs. source FAERS
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3295, 41519|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013357 vs. source FAERS
# Removing columns with more than 30% missing values: ['3130|free_cmax_margin']
# Done code 10013362 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10013364 vs. source SIDER
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10013376 vs. source SIDER
# Removing columns with more than 30% missing values: ['3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3125|ic50', '3125|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin']
# Done code 10013395 vs. source FAERS
# Removing columns with more than 30% missing values: ['3124|cmax_margin', '3124|free_cmax_margin']
# Done code 10013395 vs. source SIDER
# Removing columns with more than 30% missing values: ['3176, 31504, 41627|free_cmax_margin', '3235|cmax_margin', '3235|free_cmax_margin']
# Done code 10013496 vs. source FAERS
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3157|free_cmax_margin', '3159|cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013642 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3125|ic50', '3125|free_cmax_margin', '3126|free_cmax_margin', '3157|free_cmax_margin', '3162|ic50', '3162|cmax_margin', '3162|free_cmax_margin', '49102|free_cmax_margin']
# Done code 10013654 vs. source FAERS
# Removing columns with more than 30% missing values: ['3162|cmax_margin', '3162|free_cmax_margin']
# Done code 10013663 vs. source FAERS
# Removing columns with more than 30% missing values: []
# Done code 10013754 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3295, 41519|free_cmax_margin']
# Done code 10013756 vs. source SIDER
# Removing columns with more than 30% missing values: ['3131|cmax_margin', '3131|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin']
# Done code 10013781 vs. source FAERS
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3088, 41625|free_cmax_margin', '3126|free_cmax_margin', '3157|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '32309|ic50', '32309|cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013916 vs. source FAERS
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3083|ic50', '3083|cmax_margin', '3083|free_cmax_margin', '3088, 41625|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3196, 42784|ic50', '3196, 42784|cmax_margin', '3196, 42784|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '5434|ic50', '5434|cmax_margin', '5434|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013916 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3157|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013929 vs. source FAERS
# Removing columns with more than 30% missing values: ['3162|cmax_margin', '3162|free_cmax_margin']
# Done code 10013954 vs. source SIDER
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3175|cmax_margin', '3175|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '32309|ic50', '32309|cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013983 vs. source FAERS
# Removing columns with more than 30% missing values: ['3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3295, 41519|free_cmax_margin']
# Done code 10013983 vs. source SIDER
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3081|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '32309|ic50', '32309|cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013985 vs. source FAERS
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3081|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10013985 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin']
# Done code 10014326 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3159|cmax_margin', '3159|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3185, 41522|cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3295, 41519|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10014328 vs. source SIDER
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin', '3157|free_cmax_margin', '49102|free_cmax_margin', '5451|free_cmax_margin']
# Done code 10014387 vs. source FAERS
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '3087|cmax_margin', '3087|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '5451|ic50', '5451|free_cmax_margin']
# Done code 10014387 vs. source SIDER
# Removing columns with more than 30% missing values: ['3131|cmax_margin', '3131|free_cmax_margin']
# Done code 10014408 vs. source SIDER
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10014522 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10014706 vs. source FAERS
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3157|free_cmax_margin', '32309|ic50', '32309|cmax_margin']
# Done code 10014706 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin']
# Done code 10014733 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin']
# Done code 10014742 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3130|free_cmax_margin', '3134, 18942|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin']
# Done code 10014928 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10015683 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5426|ic50', '5426|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10015832 vs. source FAERS
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3082|ic50', '3082|cmax_margin', '3082|free_cmax_margin', '3083|ic50', '3083|cmax_margin', '3083|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3126|free_cmax_margin', '3130|ic50', '3130|cmax_margin', '3130|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3196, 42784|ic50', '3196, 42784|cmax_margin', '3196, 42784|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '5363|ic50', '5363|cmax_margin', '5363|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5434|ic50', '5434|cmax_margin', '5434|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10015832 vs. source SIDER
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10015929 vs. source SIDER
# Removing columns with more than 30% missing values: ['41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin']
# Done code 10016256 vs. source SIDER
# Removing columns with more than 30% missing values: ['49102|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10016338 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin']
# Done code 10016801 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin']
# Done code 10016807 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10017528 vs. source FAERS
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10017537 vs. source FAERS
# Failed to get cutoff for assay 3132 vs. param type cmax_margin; skipping
# Failed to get cutoff for assay 3132 vs. param type free_cmax_margin; skipping
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3126|free_cmax_margin', '3130|ic50', '3130|cmax_margin', '3130|free_cmax_margin', '3132|ic50', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '32309|ic50', '32309|cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '5363|ic50', '5363|cmax_margin', '5363|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5434|ic50', '5434|cmax_margin', '5434|free_cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|free_cmax_margin']
# Done code 10017600 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10017886 vs. source SIDER
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin']
# Done code 10017984 vs. source SIDER
# Removing columns with more than 30% missing values: ['3176, 31504, 41627|free_cmax_margin', '49102|free_cmax_margin']
# Done code 10018100 vs. source FAERS
# Removing columns with more than 30% missing values: ['3176, 31504, 41627|free_cmax_margin', '49102|free_cmax_margin']
# Done code 10018101 vs. source FAERS
# Failed to get cutoff for assay 13316 vs. param type cmax_margin; skipping
# Failed to get cutoff for assay 13316 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13316|ic50']
# Done code 10018304 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10018365 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10018429 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin']
# Done code 10018713 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10018800 vs. source SIDER
# Removing columns with more than 30% missing values: ['3124|free_cmax_margin', '3215|cmax_margin', '3215|free_cmax_margin']
# Done code 10019063 vs. source FAERS
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5426|cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5450|cmax_margin', '5450|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10019070 vs. source FAERS
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10019237 vs. source SIDER
# Failed to get cutoff for assay 3187 vs. param type free_cmax_margin; skipping
# ...
# Done code 10043118 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10043189 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10043190 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10043248 vs. source SIDER
# Removing columns with more than 30% missing values: ['3130|free_cmax_margin']
# Done code 10043296 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3130|ic50', '3130|cmax_margin', '3130|free_cmax_margin', '3131|cmax_margin', '3131|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3295, 41519|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10043354 vs. source SIDER
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3083|ic50', '3083|cmax_margin', '3083|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3196, 42784|ic50', '3196, 42784|cmax_margin', '3196, 42784|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '49102|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10043528 vs. source SIDER
# Removing columns with more than 30% missing values: ['3131|cmax_margin', '3131|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin']
# Done code 10043949 vs. source SIDER
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3196, 42784|ic50', '3196, 42784|cmax_margin', '3196, 42784|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin']
# Done code 10044066 vs. source SIDER
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3119|ic50', '3119|cmax_margin', '3119|free_cmax_margin', '3126|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3184, 14955, 15257, 41517, 42788|cmax_margin', '3184, 14955, 15257, 41517, 42788|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '49102|free_cmax_margin', '5425|cmax_margin', '5425|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10044074 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3159|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin']
# Done code 10044565 vs. source FAERS
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3159|free_cmax_margin']
# Done code 10044565 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '3295, 41519|free_cmax_margin']
# Done code 10044684 vs. source SIDER
# Removing columns with more than 30% missing values: ['3130|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin', '5363|cmax_margin', '5363|free_cmax_margin']
# Done code 10046542 vs. source SIDER
# Removing columns with more than 30% missing values: ['3134, 18942|free_cmax_margin']
# Done code 10046543 vs. source FAERS
# Removing columns with more than 30% missing values: ['3124|free_cmax_margin', '3130|free_cmax_margin']
# Done code 10046555 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: []
# Done code 10046798 vs. source SIDER
# Failed to get cutoff for assay 31453 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: []
# Done code 10046805 vs. source SIDER
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10046806 vs. source SIDER
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10047091 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: []
# Done code 10047163 vs. source SIDER
# Removing columns with more than 30% missing values: ['3130|ic50', '3130|cmax_margin', '3130|free_cmax_margin', '3131|cmax_margin', '3131|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '41704, 42863|ic50', '41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin', '5363|ic50', '5363|cmax_margin', '5363|free_cmax_margin']
# Done code 10047513 vs. source SIDER
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['32309|ic50', '32309|cmax_margin']
# Done code 10047899 vs. source FAERS
# Failed to get cutoff for assay 5528 vs. param type cmax_margin; skipping
# Failed to get cutoff for assay 5528 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: []
# Done code 10047924 vs. source FAERS
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin']
# Done code 10047924 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3125|ic50', '3125|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3235|cmax_margin', '3235|free_cmax_margin']
# Done code 10048010 vs. source FAERS
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3125|ic50', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3162|cmax_margin', '3162|free_cmax_margin', '3235|cmax_margin', '3235|free_cmax_margin']
# Done code 10048010 vs. source SIDER
# Removing columns with more than 30% missing values: ['3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin']
# Done code 10048232 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10048302 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10048843 vs. source FAERS
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '3295, 41519|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin']
# Done code 10050823 vs. source SIDER
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10052639 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3124|ic50', '3124|cmax_margin', '3124|free_cmax_margin', '3126|free_cmax_margin', '3130|cmax_margin', '3130|free_cmax_margin', '3131|cmax_margin', '3131|free_cmax_margin', '3134, 18942|cmax_margin', '3134, 18942|free_cmax_margin', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3295, 41519|free_cmax_margin', '3483, 41521, 42787|cmax_margin', '3483, 41521, 42787|free_cmax_margin', '49102|free_cmax_margin', '5363|ic50', '5363|cmax_margin', '5363|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10052736 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10052741 vs. source SIDER
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10052897 vs. source SIDER
# Removing columns with more than 30% missing values: []
# Done code 10053104 vs. source FAERS
# Removing columns with more than 30% missing values: []
# Done code 10053123 vs. source SIDER
# Removing columns with more than 30% missing values: ['13013|ic50', '13013|cmax_margin', '13013|free_cmax_margin', '3124|free_cmax_margin', '3157|free_cmax_margin']
# Done code 10053198 vs. source SIDER
# Removing columns with more than 30% missing values: ['41629|cmax_margin', '41629|free_cmax_margin', '41630|cmax_margin', '41630|free_cmax_margin', '5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10053759 vs. source SIDER
# Failed to get cutoff for assay 5426 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3185, 41522|cmax_margin', '3295, 41519|free_cmax_margin', '5426|ic50', '5426|cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin']
# Done code 10054089 vs. source SIDER
# Removing columns with more than 30% missing values: ['3134, 18942|free_cmax_margin']
# Done code 10056325 vs. source SIDER
# Removing columns with more than 30% missing values: ['3134, 18942|free_cmax_margin']
# Done code 10056988 vs. source SIDER
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10057190 vs. source FAERS
# Removing columns with more than 30% missing values: ['41704, 42863|cmax_margin', '41704, 42863|free_cmax_margin']
# Done code 10057668 vs. source FAERS
# Removing columns with more than 30% missing values: ['3087|cmax_margin', '3087|free_cmax_margin']
# Done code 10058675 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3157|ic50', '3157|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3295, 41519|free_cmax_margin', '49102|free_cmax_margin', '5451|ic50', '5451|cmax_margin', '5451|free_cmax_margin']
# Done code 10058920 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin']
# Done code 10058929 vs. source SIDER
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin']
# Done code 10061116 vs. source SIDER
# Removing columns with more than 30% missing values: ['3124|cmax_margin', '3124|free_cmax_margin', '3130|free_cmax_margin', '3162|cmax_margin', '3162|free_cmax_margin']
# Done code 10061355 vs. source FAERS
# Removing columns with more than 30% missing values: []
# Done code 10061461 vs. source SIDER
# Removing columns with more than 30% missing values: ['3157|ic50', '3157|free_cmax_margin', '3159|free_cmax_margin', '3163, 16324, 17275|free_cmax_margin', '3197, 41523, 42786|cmax_margin', '3197, 41523, 42786|free_cmax_margin', '3295, 41519|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin']
# Done code 10061536 vs. source SIDER
# Failed to get cutoff for assay 32309 vs. param type free_cmax_margin; skipping
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|cmax_margin', '13034, 41518, 42789|free_cmax_margin', '3088, 41625|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '32309|ic50', '32309|cmax_margin', '49102|free_cmax_margin', '5449|free_cmax_margin']
# Done code 10061920 vs. source FAERS
# Removing columns with more than 30% missing values: ['3088, 41625|free_cmax_margin', '3215|ic50', '3215|cmax_margin', '3215|free_cmax_margin', '5449|free_cmax_margin']
# Done code 10061920 vs. source SIDER
# Removing columns with more than 30% missing values: ['3159|cmax_margin', '3159|free_cmax_margin', '3295, 41519|free_cmax_margin']
# Done code 10066364 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3159|free_cmax_margin', '3295, 41519|free_cmax_margin', '5449|cmax_margin', '5449|free_cmax_margin']
# Done code 10068758 vs. source FAERS
# Removing columns with more than 30% missing values: ['41630|free_cmax_margin']
# Done code 10069782 vs. source FAERS
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10074170 vs. source FAERS
# Removing columns with more than 30% missing values: ['3279|ic50', '3279|cmax_margin', '3279|free_cmax_margin']
# Done code 10074171 vs. source FAERS
# Removing columns with more than 30% missing values: []
# Done code 10074484 vs. source SIDER
# Removing columns with more than 30% missing values: ['3159|free_cmax_margin', '3295, 41519|free_cmax_margin']
# Done code 10078070 vs. source SIDER
# Removing columns with more than 30% missing values: ['5437|cmax_margin', '5437|free_cmax_margin']
# Done code 10078904 vs. source SIDER
# Removing columns with more than 30% missing values: ['3124|cmax_margin', '3124|free_cmax_margin']
# Done code 10079102 vs. source FAERS
# Removing columns with more than 30% missing values: ['13034, 41518, 42789|free_cmax_margin', '3124|free_cmax_margin']
# Done code 10079102 vs. source SIDER
# Removing columns with more than 30% missing values: ['3126|free_cmax_margin', '3130|ic50', '3130|cmax_margin', '3130|free_cmax_margin', '3131|cmax_margin', '3131|free_cmax_margin', '3176, 31504, 41627|free_cmax_margin', '49102|free_cmax_margin', '5427, 5494, 41701|cmax_margin', '5427, 5494, 41701|free_cmax_margin']
# Done code 10080276 vs. source SIDER

# %% [markdown]
# From this output, the 1se_coeff is what we analyze later

# %%
df1 = pd.DataFrame(combined_cv_stats)
df1.to_csv(PATH_DATA_OUTPUT + 'multivariate_cv_stats_update.csv', index=False)

df2 = pd.DataFrame(combined_variables)
df2.to_csv(PATH_DATA_OUTPUT + 'multivariate_final_variable_update.csv', index=False)

df3 = pd.DataFrame(combined_cv_variables)
df3.to_csv(PATH_DATA_OUTPUT + 'multivariate_cv_variable_update.csv', index=False)

# %%
print('Script complete')
# Out:
# Script complete
